# %%
# %run train.py --data PEMS08 --epochs 200 --save logs/TrendGCN
# Out:
# Perform shuffle on the dataset
# Namespace(device='cuda:1', data='data//PEMS08', input_dim=3, batch_size=64, learning_rate=0.001, dropout=0.1, weight_decay=0.0001, epochs=200, channels=96, print_every=50, save='logs/TrendGCN', expid=1, es_patience=100, trainflag='Fusion')
# Ranger optimizer loaded.
# Gradient Centralization usage = True
# GC applied to both conv and fc layers
# The number of parameters: 2205746
# TEDDCF(
#   (Temb): TemporalEmbedding()
#   (start_conv): Conv2d(3, 96, kernel_size=(1, 1), stride=(1, 1))
#   (glu): GLU(
#     (conv1): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#     (conv2): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#     (conv3): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (regression_layer): Conv2d(192, 12, kernel_size=(1, 12), stride=(1, 1))
#   (temporal_conv): TemporalConvNet(
#     (conv): Conv2d(192, 192, kernel_size=(1, 2), stride=(1, 1), padding=(0, 1))
# ...

# %%
import torch
import time
time.sleep(10)
torch.cuda.empty_cache()  # 这行代码可以帮助释放不再使用的缓存内存

# %%
# %run train.py --data PEMS04 --epochs 200 --save logs/TrendGCN
# Out:
# Perform shuffle on the dataset
# Namespace(device='cuda:1', data='data//PEMS04', input_dim=3, batch_size=64, learning_rate=0.001, dropout=0.1, weight_decay=0.0001, epochs=200, channels=96, print_every=50, save='logs/TrendGCN', expid=1, es_patience=100, trainflag='Fusion')
# Ranger optimizer loaded.
# Gradient Centralization usage = True
# GC applied to both conv and fc layers
# The number of parameters: 1707500
# TEDDCF(
#   (Temb): TemporalEmbedding()
#   (start_conv): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#   (glu): GLU(
#     (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#     (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#     (conv3): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (regression_layer): Conv2d(128, 12, kernel_size=(1, 12), stride=(1, 1))
#   (temporal_conv): TemporalConvNet(
#     (conv): Conv2d(128, 128, kernel_size=(1, 2), stride=(1, 1), padding=(0, 1))
# ...

# %%
import torch
import time
time.sleep(10)
torch.cuda.empty_cache()  # 这行代码可以帮助释放不再使用的缓存内存

# %%
# %run train.py --data PEMS03 --epochs 200 --save logs/TrendGCN
# Out:
# Perform shuffle on the dataset
# Namespace(device='cuda:1', data='data//PEMS03', input_dim=3, batch_size=64, learning_rate=0.001, dropout=0.1, weight_decay=0.0001, epochs=200, channels=96, print_every=50, save='logs/TrendGCN', expid=1, es_patience=100, trainflag='Fusion')
# Ranger optimizer loaded.
# Gradient Centralization usage = True
# GC applied to both conv and fc layers
# The number of parameters: 830538
# TEDDCF(
#   (Temb): TemporalEmbedding()
#   (start_conv): Conv2d(3, 32, kernel_size=(1, 1), stride=(1, 1))
#   (glu): GLU(
#     (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (conv3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (regression_layer): Conv2d(64, 12, kernel_size=(1, 12), stride=(1, 1))
#   (temporal_conv): TemporalConvNet(
#     (conv): Conv2d(64, 64, kernel_size=(1, 2), stride=(1, 1), padding=(0, 1))
# ...
